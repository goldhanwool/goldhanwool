# %% [markdown]
# ## 크롤링 원본

# %%
from urllib.error import HTTPError
import urllib.request 
from selenium import webdriver
import time
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm_notebook
import pandas as pd


# url리스트 엑셀파일 부르기
url_load = pd.read_excel("todayHouse_url.xlsx")
num_list=len(url_load)
print(num_list)

df = pd.DataFrame()
for i in range(0, num_list):
    url = url_load['url'][i]
    driver = webdriver.Chrome("chromedriver.exe")  # 윈도우는 "chromedriver.exe"
    driver.get(url)   # url 글 띄우기 
    
    time.sleep(1)
    
    for i in range(1, 4):
        for page in range(0, 5):
            try:   
                dict = {}
                target_info = {}
    #             #카테고리수집
    #             category = driver.find_element_by_css_selector('.commerce-category-breadcrumb').text
    #             target_info['category'] = category
    #             print(category)
    #             #제품명 수집
    #             product_name = driver.find_element_by_css_selector('.production-selling-header__title').text
    #             target_info['product_name'] = product_name
    #             print(product)
    #             #제품가격 수집
    #             product_price = driver.find_element_by_css_selector('.production-selling-header__price__price').text
    #             target_info['product_price'] = product_price
    #             print(product_price)


    #             review_overalls = driver.find_elements_by_css_selector('.production-review-item')
    #             review_num = len(review_overalls[i].text.split('\n'))    

    #             target_info = {}

    #             #  user_id
    #             user = review_overalls[i].text.split('\n')[0]
    #             target_info['user'] = user

    #             # rating
    #             ratings = driver.find_elements_by_css_selector(".production-review-item__writer__info__total-star")
    #             rating = ratings[i].get_attribute('aria-label')
    #             target_info['rating'] = rating

    #             # date
    #             date = review_overalls[i].text.split('\n')[1]
    #             target_info['date'] = date

    #             # review
    #             review = review_overalls[i].text.split('\n')[-2]
    #             target_info['review'] = review 
                
                user_name = driver.find_elements_by_css_selector('.production-review-item__writer__info__name')
                user_name_list = []
                for i in user_name:
                    user_name_list.append(i.text)
                print(user_name_list)

                list_num = len(user_name)           

                
                product_name = driver.find_elements_by_css_selector('.production-selling-header__title__name')
                product_name_list = []
                for num in range(1,list_num+1):
                    for i in product_name:
                        product_name_list.append(i.text)
                print(product_name_list)
                
                product_price = driver.find_elements_by_xpath('/html/body/div[1]/div/div[2]/div[1]/div/div[2]/div[1]/div/p[2]/span[1]/span[2]/span/span[1]')
                product_price_list =[]
                for num in range(1,list_num+1):
                    for i in product_price:
                        product_price_list.append(i.text)
                print(product_price_list)
                
                product_score = driver.find_elements_by_css_selector('.badge__pc')
                product_score_list = []   
                for num in range(1,list_num+1):
                    for i in product_score:
                        product_score_list.append(i.text)
                print(product_score_list)
        
                    
                list_num = len(user_name) 

                product_score = driver.find_elements_by_css_selector('.badge__pc')
                product_score_list = []   
                for num in range(1,list_num+1):
                    for i in product_score:
                        product_score_list.append(i.text)
                print(product_score_list)


                #별점 총점
                score = []
                for num in range(1,list_num+1):
                    star = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[5]/div/div[1]/div/section[2]/div/div[3]/div[%s]/article/div[1]/div/button/span' %num)
                    score.append(star.get_attribute("aria-label"))
                print('총점:', score)
                # print(star)


                # 리뷰내용
                # date
                date = driver.find_elements_by_css_selector('.production-review-item__writer__info__date')
                date_list = []   
                for i in date:
                    date_list.append(i.text)
                print(date_list)


                content = driver.find_elements_by_css_selector('.production-review-item__description')   
                content_list = []
                for i in content:
                    content_list.append(i.text)
                print(content_list)


                health = []
                for num in range(1,list_num+1):
                    try:
                        a = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[5]/div/div[1]/div/section[2]/div/div[3]/div[%s]/article/div[2]/div[2]/span[2]' %num)
                        health.append(a.get_attribute("aria-label"))
                    except:
                        health.append("none")

                price = []
                for num in range(1,list_num+1):
                    try:
                        a = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[5]/div/div[1]/div/section[2]/div/div[3]/div[%s]/article/div[2]/div[1]/span[2]' %num)
                        price.append(a.get_attribute("aria-label"))
                    except:
                        price.append("none")     


                design = []
                for num in range(1,list_num+1):
                    try:
                        a = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[5]/div/div[1]/div/section[2]/div/div[3]/div[%s]/article/div[2]/div[1]/span[4]' %num)
                        design.append(a.get_attribute("aria-label"))
                    except:
                        design.append("none")     


                delivery = []
                for num in range(1,list_num+1):
                    try:
                        a = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[5]/div/div[1]/div/section[2]/div/div[3]/div[%s]/article/div[2]/div[2]/span[4]' %num)
                        delivery.append(a.get_attribute("aria-label"))
                    except:
                        delivery.append("none")     


                #상품옵션    
                # item_name = driver.find_elements_by_css_selector('.production-review-item__name')    

                # help_text = []
                help_text = []
                for num in range(1,list_num+1):
                    try:
                        a = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[5]/div/div[1]/div/section[2]/div/div[3]/div[%s]/article/div[4]/div/span' %num)
                        help_text.append(a)
                    except:
                        try:
                            a = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[5]/div/div[1]/div/section[2]/div/div[3]/div[%s]/article/div[3]/div/span' %num)               
                            help_text.append(a)    
                        except:
                            help_text.append('none')

                help_text_list = []
                for i in help_text:
                    try :
                        if i != 'none':
                            help_text_list.append(i.text)
                        else : 
                            help_text_list.append('none')
                    except:
                        continue 

                    # 리스트 보기
                print(health)
                print(price)
                print(design) 
                print(delivery) 
                print(help_text_list)

                all_info = []
                for i in range(len(content)):
                    all_info.append(product_name_list[i])
                    all_info.append(product_price_list[i])
                    all_info.append(product_score_list[i])
                    all_info.append(date_list[i])
                    all_info.append(user_name_list[i])
                    all_info.append(score[i])
                    all_info.append(health[i])
                    all_info.append(price[i])
                    all_info.append(design[i])
                    all_info.append(delivery[i])
                    all_info.append(help_text_list[i])
                    all_info.append(content_list[i])

    #             all_info =  [ x for x in zip(product_name_list, product_price_list, product_score_list, date_list, user_name_list, score, health, price, design, delivery, help_text_list, content_list)]
    #             df = pd.DataFrame(all_info, columns=['상품명', '가격', '총점', '날짜', '아이디','별점','내구성','가격', '디자인','배송','좋아요','내용'])
    #             df.to_excel("{}.xlsx".format(page))

                dict[page] = all_info
#                 result_df = pd.DataFrame.from_dict(dict, 'index')
                result_df = pd.DataFrame(dict)
                df = pd.concat([df, result_df])
                    
                pages = driver.find_element_by_css_selector("._2XI47._3I7ex")
                pages.click()
                
                time.sleep(1)

            except:
                break 


print("완료")

# %%
df.to_excel("오늘의 집.xlsx")
